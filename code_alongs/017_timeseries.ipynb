# %% [markdown]
# ## pandas timeseries
# a series or dataframe using datetime index instead of a range index
#
# used for storing events/data that fits on a timeline
# - weather data
# - temperature readings
# - heart rate monetoring
# - quarterly sales
# - stock prices

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # creating a datetime index
# - start
# - end
# - periods
# - freq

# %%
datetimeindex = pd.date_range(start="2018-03-15", end="2019-12-31", freq="2D5H", periods=10)
datetimeindex
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-03 05:00:00',
#                '2018-01-05 10:00:00', '2018-01-07 15:00:00',
#                '2018-01-09 20:00:00', '2018-01-12 01:00:00',
#                '2018-01-14 06:00:00', '2018-01-16 11:00:00',
#                '2018-01-18 16:00:00', '2018-01-20 21:00:00'],
#               dtype='datetime64[ns]', freq='53H')

# %%
df = pd.DataFrame(
    dict(
        n = range(len(datetimeindex)),
        rand = np.random.random(len(datetimeindex))
    ),
    index=datetimeindex
)

df
# Out:
#                      n      rand
# 2018-01-01 00:00:00  0  0.382417
# 2018-01-03 05:00:00  1  0.814620
# 2018-01-05 10:00:00  2  0.375086
# 2018-01-07 15:00:00  3  0.317559
# 2018-01-09 20:00:00  4  0.265596
# 2018-01-12 01:00:00  5  0.022302
# 2018-01-14 06:00:00  6  0.907966
# 2018-01-16 11:00:00  7  0.990518
# 2018-01-18 16:00:00  8  0.780815
# 2018-01-20 21:00:00  9  0.966471

# %%
df.loc[:, "rand"]
# Out:
# 2018-01-01 00:00:00    0.382417
# 2018-01-03 05:00:00    0.814620
# 2018-01-05 10:00:00    0.375086
# 2018-01-07 15:00:00    0.317559
# 2018-01-09 20:00:00    0.265596
# 2018-01-12 01:00:00    0.022302
# 2018-01-14 06:00:00    0.907966
# 2018-01-16 11:00:00    0.990518
# 2018-01-18 16:00:00    0.780815
# 2018-01-20 21:00:00    0.966471
# Freq: 53H, Name: rand, dtype: float64

# %% [markdown]
# ### resampling
# resampling is the practice of creating new samples with a lower or higher freq than the orginal data

# %% [markdown]
# ### downsampling
# when the sample freq is lower than the orginal we can aggregate values from the orginal data

# %%
from helpers import hdisplay

resample_method = "2D"

hdisplay([
    df.head(10),
    df.resample("2D").agg({"n": "max", "rand": "sum"}).head(10)],
    ["Orginal", f"resampled using '{resample_method}'"]
)
# Out:
# <style type="text/css">
# #T_ec216 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_ec216" style='display:inline; margin-right: 50px;'>
#   <caption>Orginal</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec216_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_ec216_level0_col1" class="col_heading level0 col1" >rand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec216_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_ec216_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ec216_row0_col1" class="data row0 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row1" class="row_heading level0 row1" >2018-01-03 05:00:00</th>
#       <td id="T_ec216_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ec216_row1_col1" class="data row1 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row2" class="row_heading level0 row2" >2018-01-05 10:00:00</th>
#       <td id="T_ec216_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_ec216_row2_col1" class="data row2 col1" >0.375086</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row3" class="row_heading level0 row3" >2018-01-07 15:00:00</th>
#       <td id="T_ec216_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_ec216_row3_col1" class="data row3 col1" >0.317559</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row4" class="row_heading level0 row4" >2018-01-09 20:00:00</th>
#       <td id="T_ec216_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_ec216_row4_col1" class="data row4 col1" >0.265596</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row5" class="row_heading level0 row5" >2018-01-12 01:00:00</th>
#       <td id="T_ec216_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_ec216_row5_col1" class="data row5 col1" >0.022302</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row6" class="row_heading level0 row6" >2018-01-14 06:00:00</th>
#       <td id="T_ec216_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_ec216_row6_col1" class="data row6 col1" >0.907966</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row7" class="row_heading level0 row7" >2018-01-16 11:00:00</th>
#       <td id="T_ec216_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_ec216_row7_col1" class="data row7 col1" >0.990518</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row8" class="row_heading level0 row8" >2018-01-18 16:00:00</th>
#       <td id="T_ec216_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_ec216_row8_col1" class="data row8 col1" >0.780815</td>
#     </tr>
#     <tr>
#       <th id="T_ec216_level0_row9" class="row_heading level0 row9" >2018-01-20 21:00:00</th>
#       <td id="T_ec216_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_ec216_row9_col1" class="data row9 col1" >0.966471</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7aeb7 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_7aeb7" style='display:inline; margin-right: 50px;'>
#   <caption>resampled using '2D'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aeb7_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_7aeb7_level0_col1" class="col_heading level0 col1" >rand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aeb7_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_7aeb7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7aeb7_row0_col1" class="data row0 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row1" class="row_heading level0 row1" >2018-01-03 00:00:00</th>
#       <td id="T_7aeb7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_7aeb7_row1_col1" class="data row1 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row2" class="row_heading level0 row2" >2018-01-05 00:00:00</th>
#       <td id="T_7aeb7_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_7aeb7_row2_col1" class="data row2 col1" >0.375086</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row3" class="row_heading level0 row3" >2018-01-07 00:00:00</th>
#       <td id="T_7aeb7_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_7aeb7_row3_col1" class="data row3 col1" >0.317559</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row4" class="row_heading level0 row4" >2018-01-09 00:00:00</th>
#       <td id="T_7aeb7_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_7aeb7_row4_col1" class="data row4 col1" >0.265596</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row5" class="row_heading level0 row5" >2018-01-11 00:00:00</th>
#       <td id="T_7aeb7_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_7aeb7_row5_col1" class="data row5 col1" >0.022302</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row6" class="row_heading level0 row6" >2018-01-13 00:00:00</th>
#       <td id="T_7aeb7_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_7aeb7_row6_col1" class="data row6 col1" >0.907966</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row7" class="row_heading level0 row7" >2018-01-15 00:00:00</th>
#       <td id="T_7aeb7_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_7aeb7_row7_col1" class="data row7 col1" >0.990518</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row8" class="row_heading level0 row8" >2018-01-17 00:00:00</th>
#       <td id="T_7aeb7_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_7aeb7_row8_col1" class="data row8 col1" >0.780815</td>
#     </tr>
#     <tr>
#       <th id="T_7aeb7_level0_row9" class="row_heading level0 row9" >2018-01-19 00:00:00</th>
#       <td id="T_7aeb7_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_7aeb7_row9_col1" class="data row9 col1" >0.966471</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### upsampling
# when the sample freq is higher than the orginal we can fill between values:
# - ffill
# - bfill
# - nearest
# - interpolation
# - fillna

# %%
from helpers import hdisplay

resample_method = "6H"

hdisplay([
    df.head(10),
    df.resample(resample_method).nearest().head(10)],
    ["Orginal", f"resampled using '{resample_method}'"]
)
# Out:
# <style type="text/css">
# #T_11e88 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_11e88" style='display:inline; margin-right: 50px;'>
#   <caption>Orginal</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11e88_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_11e88_level0_col1" class="col_heading level0 col1" >rand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11e88_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_11e88_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_11e88_row0_col1" class="data row0 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row1" class="row_heading level0 row1" >2018-01-03 05:00:00</th>
#       <td id="T_11e88_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_11e88_row1_col1" class="data row1 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row2" class="row_heading level0 row2" >2018-01-05 10:00:00</th>
#       <td id="T_11e88_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_11e88_row2_col1" class="data row2 col1" >0.375086</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row3" class="row_heading level0 row3" >2018-01-07 15:00:00</th>
#       <td id="T_11e88_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_11e88_row3_col1" class="data row3 col1" >0.317559</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row4" class="row_heading level0 row4" >2018-01-09 20:00:00</th>
#       <td id="T_11e88_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_11e88_row4_col1" class="data row4 col1" >0.265596</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row5" class="row_heading level0 row5" >2018-01-12 01:00:00</th>
#       <td id="T_11e88_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_11e88_row5_col1" class="data row5 col1" >0.022302</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row6" class="row_heading level0 row6" >2018-01-14 06:00:00</th>
#       <td id="T_11e88_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_11e88_row6_col1" class="data row6 col1" >0.907966</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row7" class="row_heading level0 row7" >2018-01-16 11:00:00</th>
#       <td id="T_11e88_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_11e88_row7_col1" class="data row7 col1" >0.990518</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row8" class="row_heading level0 row8" >2018-01-18 16:00:00</th>
#       <td id="T_11e88_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_11e88_row8_col1" class="data row8 col1" >0.780815</td>
#     </tr>
#     <tr>
#       <th id="T_11e88_level0_row9" class="row_heading level0 row9" >2018-01-20 21:00:00</th>
#       <td id="T_11e88_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_11e88_row9_col1" class="data row9 col1" >0.966471</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0bf6f th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_0bf6f" style='display:inline; margin-right: 50px;'>
#   <caption>resampled using '6H'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bf6f_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_0bf6f_level0_col1" class="col_heading level0 col1" >rand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bf6f_level0_row0" class="row_heading level0 row0" >2018-01-01 00:00:00</th>
#       <td id="T_0bf6f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0bf6f_row0_col1" class="data row0 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row1" class="row_heading level0 row1" >2018-01-01 06:00:00</th>
#       <td id="T_0bf6f_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0bf6f_row1_col1" class="data row1 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row2" class="row_heading level0 row2" >2018-01-01 12:00:00</th>
#       <td id="T_0bf6f_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_0bf6f_row2_col1" class="data row2 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row3" class="row_heading level0 row3" >2018-01-01 18:00:00</th>
#       <td id="T_0bf6f_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_0bf6f_row3_col1" class="data row3 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row4" class="row_heading level0 row4" >2018-01-02 00:00:00</th>
#       <td id="T_0bf6f_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_0bf6f_row4_col1" class="data row4 col1" >0.382417</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row5" class="row_heading level0 row5" >2018-01-02 06:00:00</th>
#       <td id="T_0bf6f_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_0bf6f_row5_col1" class="data row5 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row6" class="row_heading level0 row6" >2018-01-02 12:00:00</th>
#       <td id="T_0bf6f_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_0bf6f_row6_col1" class="data row6 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row7" class="row_heading level0 row7" >2018-01-02 18:00:00</th>
#       <td id="T_0bf6f_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_0bf6f_row7_col1" class="data row7 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row8" class="row_heading level0 row8" >2018-01-03 00:00:00</th>
#       <td id="T_0bf6f_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_0bf6f_row8_col1" class="data row8 col1" >0.814620</td>
#     </tr>
#     <tr>
#       <th id="T_0bf6f_level0_row9" class="row_heading level0 row9" >2018-01-03 06:00:00</th>
#       <td id="T_0bf6f_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_0bf6f_row9_col1" class="data row9 col1" >0.814620</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## working with real data

# %%
apple = pd.read_csv("../Data/HistoricalData_Apple.csv", parse_dates=["Date"], index_col="Date")
apple.rename(columns={"Close/Last": "Close"}, inplace=True)

to_int_columns = ["Close", "Open", "High", "Low"]

apple[["Close", "Open", "High", "Low"]] = apple[["Close", "Open", "High", "Low"]].map(lambda value: value.replace("$", "")).astype("float64")

# apple = apple.astype({col : "float64" for col in to_int_columns})

apple.sort_index(inplace=True)

apple
# Out:
#              Close    Volume     Open      High     Low
# Date
# 2023-10-10  178.39  43698020  178.100  179.7200  177.95
# 2023-10-11  179.80  47551100  178.200  179.8500  177.60
# 2023-10-12  180.71  56743120  180.070  182.3400  179.04
# 2023-10-13  178.85  51456080  181.420  181.9300  178.14
# 2023-10-16  178.72  52516980  176.750  179.0750  176.51
# 2023-10-17  177.15  57549350  176.645  178.4200  174.80
# 2023-10-18  175.84  54764380  175.580  177.5750  175.11
# 2023-10-19  175.46  59302860  176.040  177.8400  175.19
# 2023-10-20  172.88  64244030  175.310  175.4200  172.64
# 2023-10-23  173.00  55980110  170.910  174.0100  169.93
# 2023-10-24  173.44  43816640  173.050  173.6700  171.45
# 2023-10-25  171.10  57156960  171.880  173.0600  170.65
# 2023-10-26  166.89  70625260  170.370  171.3775  165.67
# 2023-10-27  168.22  58499130  166.910  168.9600  166.83
# 2023-10-30  170.29  51130960  169.020  171.1700  168.87
# 2023-10-31  170.77  44846020  169.350  170.9000  167.90
# 2023-11-01  173.97  56934910  171.000  174.2300  170.12
# 2023-11-02  177.57  77334750  175.520  177.7800  175.46
# 2023-11-03  176.65  79829250  174.240  176.8200  173.35
# 2023-11-06  179.23  63841310  176.380  179.4300  176.21
# 2023-11-07  181.82  70529970  179.180  182.4400  178.97
# 2023-11-08  182.89  49340280  182.350  183.4500  181.59
# 2023-11-09  182.41  53763540  182.960  184.1200  181.81

# %%
apple.loc["2018", "Close"].max()
apple.resample("YS").mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexes\datetimes.py:611, in DatetimeIndex.get_loc(self, key)
#     610 try:
# --> 611     return self._partial_date_slice(reso, parsed)
#     612 except KeyError as err:
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexes\datetimelike.py:310, in DatetimeIndexOpsMixin._partial_date_slice(self, reso, parsed)
#     306 if len(self) and (
#     307     (t1 < self[0] and t2 < self[0]) or (t1 > self[-1] and t2 > self[-1])
#     308 ):
#     309     # we are out of range
# --> 310     raise KeyError
#     312 # TODO: does this depend on being monotonic _increasing_?
#     313
#     314 # a monotonic (sorted) series can be sliced
#
# KeyError:
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\MaxF�rsntr�m-AI23GBG\Documents\github\Databehandling AI23\code_alongs\017_timeseries.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MaxF%EF%BF%BDrsntr%EF%BF%BDm-AI23GBG/Documents/github/Databehandling%20AI23/code_alongs/017_timeseries.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> apple.loc["2018", "Close"].max()
#       <a href='vscode-notebook-cell:/c%3A/Users/MaxF%EF%BF%BDrsntr%EF%BF%BDm-AI23GBG/Documents/github/Databehandling%20AI23/code_alongs/017_timeseries.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> apple.resample("YS").mean()
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexing.py:1330, in _LocIndexer._getitem_tuple(self, tup)
#    1328 with suppress(IndexingError):
#    1329     tup = self._expand_ellipsis(tup)
# -> 1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
#    1333 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexing.py:1039, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1035 for i, key in enumerate(tup):
#    1036     if is_label_like(key):
#    1037         # We don't need to check for tuples here because those are
#    1038         #  caught by the _is_nested_tuple_indexer check above.
# -> 1039         section = self._getitem_axis(key, axis=i)
#    1041         # We should never have a scalar section here, because
#    1042         #  _getitem_lowerdim is only called after a check for
#    1043         #  is_scalar_access, which that would be.
#    1044         if section.ndim == self.ndim:
#    1045             # we're in the middle of slicing through a MultiIndex
#    1046             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File c:\Users\MaxF�rsntr�m-AI23GBG\.virtualenvs\Databehandling_AI23-lCJy1fPd\Lib\site-packages\pandas\core\indexes\datetimes.py:613, in DatetimeIndex.get_loc(self, key)
#     611             return self._partial_date_slice(reso, parsed)
#     612         except KeyError as err:
# --> 613             raise KeyError(key) from err
#     615     key = parsed
#     617 elif isinstance(key, dt.timedelta):
#     618     # GH#20464
#
# KeyError: '2018'

# %%
import seaborn as sns

data = apple.loc["2020-10"].resample("M").mean()
data = apple.loc["2020"].resample("QS").mean()
sns.lineplot(data=apple, x=apple_index, y="Open")
